# %%
pip install toad
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement toad (from versions: none)
# ERROR: No matching distribution found for toad

# %%
import pandas as pd
# import toad
